# %% [markdown]
# # Student Score Prediction
#
# Author: Andersen Chandra
#
# Data Source: https://www.kaggle.com/datasets/rabieelkharoua/students-performance-dataset
#
# ## Objective:
# This project aims to develop a predictive model for students' score/GPA using Linear Regression. This model will be trained on relevant independent variables while excluding the GradeClass and GPA columns to prevent data leakage, as GradeClass is highly correlated with GPA. The goal is to analyze how different factors influence students' academic performance and build a reliable regression model to predict GPA based on these factors.

# %% [markdown]
# ## Data Preparation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Student_performance_data _.csv')

# %%
df.head(10)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
# 5       1006   18       0          0                  1         8.191219
# 6       1007   15       0          1                  1        15.601680
# 7       1008   15       1          1                  4        15.424496
# 8       1009   17       0          0                  0         4.562008
# 9       1010   16       1          0                  1        18.444466
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
# 5         0         0                1                1       0      0
# 6        10         0                3                0       1      0
# 7        22         1                1                1       0      0
# 8         1         0                2                0       1      0
# 9         0         0                3                1       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0
# 5             0  3.084184         1.0
# 6             0  2.748237         2.0
# 7             0  1.360143         4.0
# 8             1  2.896819         2.0
# 9             0  3.573474         0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %% [markdown]
# # Data Preprocessing

# %%
df.isna().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# min           0.001057     0.000000     0.000000         0.000000
# 25%           5.043079     7.000000     0.000000         1.000000
# 50%           9.705363    15.000000     0.000000         2.000000
# 75%          14.408410    22.000000     1.000000         3.000000
# max          19.978094    29.000000     1.000000         4.000000
#
#        Extracurricular       Sports        Music  Volunteering          GPA  \
# count      2392.000000  2392.000000  2392.000000   2392.000000  2392.000000
# mean          0.383361     0.303512     0.196906      0.157191     1.906186
# std           0.486307     0.459870     0.397744      0.364057     0.915156
# min           0.000000     0.000000     0.000000      0.000000     0.000000
# 25%           0.000000     0.000000     0.000000      0.000000     1.174803
# 50%           0.000000     0.000000     0.000000      0.000000     1.893393
# 75%           1.000000     1.000000     0.000000      0.000000     2.622216
# max           1.000000     1.000000     1.000000      1.000000     4.000000
#
#         GradeClass
# count  2392.000000
# mean      2.983696
# std       1.233908
# min       0.000000
# 25%       2.000000
# 50%       4.000000
# 75%       4.000000
# max       4.000000

# %%
df = pd.get_dummies(df, columns=['Ethnicity'])

# %%
df.head(10)
# Out:
#    StudentID  Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  \
# 0       1001   17       1                  2        19.833723         7
# 1       1002   18       0                  1        15.408756         0
# 2       1003   15       0                  3         4.210570        26
# 3       1004   17       1                  3        10.028829        14
# 4       1005   17       1                  2         4.672495        17
# 5       1006   18       0                  1         8.191219         0
# 6       1007   15       0                  1        15.601680        10
# 7       1008   15       1                  4        15.424496        22
# 8       1009   17       0                  0         4.562008         1
# 9       1010   16       1                  1        18.444466         0
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1                2                0       0      1             0
# 1         0                1                0       0      0             0
# 2         0                2                0       0      0             0
# 3         0                3                1       0      0             0
# 4         1                3                0       0      0             0
# 5         0                1                1       0      0             0
# 6         0                3                0       1      0             0
# 7         1                1                1       0      0             0
# 8         0                2                0       1      0             1
# 9         0                3                1       0      0             0
#
#         GPA  GradeClass  Ethnicity_0  Ethnicity_1  Ethnicity_2  Ethnicity_3
# 0  2.929196         2.0         True        False        False        False
# 1  3.042915         1.0         True        False        False        False
# 2  0.112602         4.0        False        False         True        False
# 3  2.054218         3.0         True        False        False        False
# 4  1.288061         4.0         True        False        False        False
# 5  3.084184         1.0         True        False        False        False
# 6  2.748237         2.0        False         True        False        False
# 7  1.360143         4.0        False         True        False        False
# 8  2.896819         2.0         True        False        False        False
# 9  3.573474         0.0         True        False        False        False

# %%
df = df.rename(columns={'Ethnicity_0': 'Caucasian', 'Ethnicity_1': 'African_American', 'Ethnicity_2' : 'Asian', 'Ethnicity_3': 'Other'})

# %%
df.head()
# Out:
#    StudentID  Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  \
# 0       1001   17       1                  2        19.833723         7
# 1       1002   18       0                  1        15.408756         0
# 2       1003   15       0                  3         4.210570        26
# 3       1004   17       1                  3        10.028829        14
# 4       1005   17       1                  2         4.672495        17
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1                2                0       0      1             0
# 1         0                1                0       0      0             0
# 2         0                2                0       0      0             0
# 3         0                3                1       0      0             0
# 4         1                3                0       0      0             0
#
#         GPA  GradeClass  Caucasian  African_American  Asian  Other
# 0  2.929196         2.0       True             False  False  False
# 1  3.042915         1.0       True             False  False  False
# 2  0.112602         4.0      False             False   True  False
# 3  2.054218         3.0       True             False  False  False
# 4  1.288061         4.0       True             False  False  False

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                    StudentID       Age    Gender  ParentalEducation  \
# StudentID           1.000000 -0.042255 -0.014625          -0.002307
# Age                -0.042255  1.000000  0.044895           0.025099
# Gender             -0.014625  0.044895  1.000000           0.006771
# ParentalEducation  -0.002307  0.025099  0.006771           1.000000
# StudyTimeWeekly     0.026976 -0.006800  0.011469          -0.011051
# Absences            0.014841 -0.011511  0.021479           0.036518
# Tutoring           -0.007834 -0.012076 -0.031597          -0.017340
# ParentalSupport     0.003016  0.033197  0.008065          -0.017463
# Extracurricular    -0.003611 -0.025061 -0.005964           0.007479
# Sports             -0.020703 -0.046320 -0.008897           0.002029
# Music              -0.005468 -0.003492  0.007109           0.039439
# Volunteering        0.008011  0.013074 -0.000200           0.011960
# GPA                -0.002697  0.000275 -0.013360          -0.035854
# GradeClass         -0.098500 -0.006250  0.022998           0.041031
# Caucasian          -0.003120  0.027792 -0.002709          -0.017312
# African_American    0.028838 -0.020276 -0.020383          -0.012291
# Asian              -0.013322  0.010054  0.010295           0.003438
# Other              -0.016584 -0.033391  0.018985           0.042257
#
#                    StudyTimeWeekly  Absences  Tutoring  ParentalSupport  \
# StudentID                 0.026976  0.014841 -0.007834         0.003016
# Age                      -0.006800 -0.011511 -0.012076         0.033197
# Gender                    0.011469  0.021479 -0.031597         0.008065
# ParentalEducation        -0.011051  0.036518 -0.017340        -0.017463
# StudyTimeWeekly           1.000000  0.009326  0.028930         0.035800
# Absences                  0.009326  1.000000 -0.015534         0.002108
# Tutoring                  0.028930 -0.015534  1.000000        -0.000824
# ParentalSupport           0.035800  0.002108 -0.000824         1.000000
# Extracurricular          -0.022860  0.000360  0.004865        -0.008381
# Sports                    0.006836  0.041454  0.006278        -0.006176
# Music                     0.007791 -0.008692 -0.011385         0.035122
# Volunteering             -0.016604 -0.018528 -0.050898        -0.006036
# GPA                       0.179275 -0.919314  0.145119         0.190774
# GradeClass               -0.134131  0.728633 -0.111695        -0.136823
# Caucasian                -0.004199  0.031660  0.016736        -0.001745
# African_American          0.014193 -0.023062 -0.014867        -0.032391
# Asian                    -0.031638 -0.006022  0.012225         0.018394
# Other                     0.030773 -0.014158 -0.024853         0.022973
#
#                    Extracurricular    Sports     Music  Volunteering  \
# StudentID                -0.003611 -0.020703 -0.005468      0.008011
# Age                      -0.025061 -0.046320 -0.003492      0.013074
# Gender                   -0.005964 -0.008897  0.007109     -0.000200
# ParentalEducation         0.007479  0.002029  0.039439      0.011960
# StudyTimeWeekly          -0.022860  0.006836  0.007791     -0.016604
# Absences                  0.000360  0.041454 -0.008692     -0.018528
# Tutoring                  0.004865  0.006278 -0.011385     -0.050898
# ParentalSupport          -0.008381 -0.006176  0.035122     -0.006036
# Extracurricular           1.000000 -0.011820 -0.014191     -0.007427
# Sports                   -0.011820  1.000000 -0.020474     -0.002799
# Music                    -0.014191 -0.020474  1.000000      0.017224
# Volunteering             -0.007427 -0.002799  0.017224      1.000000
# GPA                       0.094078  0.057859  0.073318      0.003258
# GradeClass               -0.069733 -0.026654 -0.036065      0.013156
# Caucasian                -0.016711 -0.000616  0.017524     -0.006269
# African_American          0.046771 -0.001419 -0.015788     -0.018442
# Asian                    -0.009045  0.016819  0.003847      0.026364
# Other                    -0.024021 -0.019991 -0.013453      0.000410
#
#                         GPA  GradeClass  Caucasian  African_American  \
# StudentID         -0.002697   -0.098500  -0.003120          0.028838
# Age                0.000275   -0.006250   0.027792         -0.020276
# Gender            -0.013360    0.022998  -0.002709         -0.020383
# ParentalEducation -0.035854    0.041031  -0.017312         -0.012291
# StudyTimeWeekly    0.179275   -0.134131  -0.004199          0.014193
# Absences          -0.919314    0.728633   0.031660         -0.023062
# Tutoring           0.145119   -0.111695   0.016736         -0.014867
# ParentalSupport    0.190774   -0.136823  -0.001745         -0.032391
# Extracurricular    0.094078   -0.069733  -0.016711          0.046771
# Sports             0.057859   -0.026654  -0.000616         -0.001419
# Music              0.073318   -0.036065   0.017524         -0.015788
# Volunteering       0.003258    0.013156  -0.006269         -0.018442
# GPA                1.000000   -0.782835  -0.033402          0.022415
# GradeClass        -0.782835    1.000000   0.027572         -0.017561
# Caucasian         -0.033402    0.027572   1.000000         -0.514228
# African_American   0.022415   -0.017561  -0.514228          1.000000
# Asian              0.008614   -0.007963  -0.499076         -0.251961
# Other              0.014511   -0.012123  -0.322806         -0.162970
#
#                       Asian     Other
# StudentID         -0.013322 -0.016584
# Age                0.010054 -0.033391
# Gender             0.010295  0.018985
# ParentalEducation  0.003438  0.042257
# StudyTimeWeekly   -0.031638  0.030773
# Absences          -0.006022 -0.014158
# Tutoring           0.012225 -0.024853
# ParentalSupport    0.018394  0.022973
# Extracurricular   -0.009045 -0.024021
# Sports             0.016819 -0.019991
# Music              0.003847 -0.013453
# Volunteering       0.026364  0.000410
# GPA                0.008614  0.014511
# GradeClass        -0.007963 -0.012123
# Caucasian         -0.499076 -0.322806
# African_American  -0.251961 -0.162970
# Asian              1.000000 -0.158168
# Other             -0.158168  1.000000

# %%
plt.figure(figsize=(14,14))
sns.heatmap(correlation_matrix, annot=True, cmap='magma', fmt='.1f')
plt.title("Correlation Matrix Visualization", fontsize=18)
plt.show()

# %%
data_without_gradeclass = df.drop(columns=['GradeClass'])
correlation = data_without_gradeclass.corr(method='pearson')
data_corr = correlation['GPA'].sort_values(ascending=False)
print(data_corr)
# Out:
# GPA                  1.000000
# ParentalSupport      0.190774
# StudyTimeWeekly      0.179275
# Tutoring             0.145119
# Extracurricular      0.094078
# Music                0.073318
# Sports               0.057859
# African_American     0.022415
# Other                0.014511
# Asian                0.008614
# Volunteering         0.003258
# Age                  0.000275
# StudentID           -0.002697
# Gender              -0.013360
# Caucasian           -0.033402
# ParentalEducation   -0.035854
# Absences            -0.919314
# Name: GPA, dtype: float64

# %% [markdown]
# ## Model Training and Evaluation

# %%
from sklearn.model_selection import train_test_split

x = df.drop(columns=['GPA', 'GradeClass'], axis=1)
y = df['GPA']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = linear_reg.predict(X_test)
print("Mean Squared Error: ", mean_squared_error(y_pred, y_test))
print("R^2 Score: ", r2_score(y_pred, y_test))
# Out:
# Mean Squared Error:  0.03901121121334942
# R^2 Score:  0.9493417094798442

# %%
y_train_pred = linear_reg.predict(X_train)
y_test_pred = linear_reg.predict(X_test)

r2_train_score = r2_score(y_train_pred, y_train)
r2_test_score = r2_score(y_test_pred, y_test)

mse_train_score = mean_squared_error(y_train, y_train_pred)
mse_test_score = mean_squared_error(y_test, y_test_pred)

print("Training Set r2 score: ", r2_train_score)
print("Testing Set r2 score: ", r2_test_score)
print("Training Set MSE score: ", mse_train_score)
print("Testing Set MSE score: ", mse_test_score)
# Out:
# Training Set r2 score:  0.9521598793434116
# Testing Set r2 score:  0.9493417094798442
# Training Set MSE score:  0.03833239011912433
# Testing Set MSE score:  0.03901121121334942

# %%
residual = y_test - linear_reg.predict(X_test)
plt.figure(figsize=(10, 10))
sns.histplot(residual, bins=30, kde=True)
plt.title("Residuals Dist")
plt.show()

# %%
sns.scatterplot(x=y_pred, y=residual)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel("Predicted GPA")
plt.ylabel("Residuals")
plt.title("Residuals VS Predicted GPA")
plt.show()

# %% [markdown]
# ## Saving Model

# %%
import joblib

joblib.dump(linear_reg, "linear-regression-model.pkl")
# Out:
# ['linear-regression-model.pkl']

# %% [markdown]
# # Conclusion
#
# This project successfully develop a predictive model to predict students' GPA using Linear Regression. The workflow begins with data preprocessing, where we check for missing values, duplicate rows in the dataset and apply one-hot encoding to the ethnicity column to prevent the model from assuming any inherent order. We also analyze and visualize feature correlations using a heatmap, ensuring that GradeClass column is excluded from correlation mapping to prevent data leakage, as it is derived from GPA.
#
# Next, we split the dataset into training and testing set and train the Linear Regression model. The model performance is evaluated using RSE and R^2 Score, achieving MSE score of 0.03 and R^2 score of 0.94, indicating strong predictive accuracy. the MSE and R^2 score between the training and the testing set is also similar, showing that the model perform well when being trained and tested.
#
# Residual analysis shows that errors are normally distributed and centered around zero, with no clear pattern in the residual vs. predicted GPA scatterplot, suggesting that the model makes unbiased predictions. Finally, we save the model with joblib for the future use.
